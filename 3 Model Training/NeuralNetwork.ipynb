# %%
import pandas as pd

import torch
import torch.nn as nn  # neural network
import torch.nn.functional as F  # raw function
import torch.optim as optim  # optimizer
from torch.utils.data import TensorDataset, DataLoader

from copy import deepcopy
from datetime import datetime

from sklearn.model_selection import train_test_split

# %% [markdown]
# # Neural Network

# %%
# My early stopping class
class EarlyStopping:
    def __init__(self, patience=7, delta=0.001):
        """
        Early stops the training if validation loss doesn't improve after a given patience.
        :param patience: How long to wait after last time validation loss improved.
        :param delta: Minimum change in the monitored quantity to qualify as an improvement.
        """
        self.patience = patience
        self.counter = 0
        self.total_run = 0
        self.best_score = None
        self.early_stop = False
        self.delta = delta
        self.model = None

    def __call__(self, val_loss, model):
        """
        Early stopping function.
        :param val_loss: the validation loss current
        :param model: the model to save
        :return: true is early stopping should be used
        """
        self.total_run += 1
        print(f"Run number {self.total_run} ", end="")
        # if the best score is not set, set it and save the model
        if self.best_score is None:
            print(f"Initial validation loss: {val_loss}")
            self.best_score = val_loss
            self.model = deepcopy(model)
            return False, self.model

        # if the score is worse than the best score, increment the counter
        elif val_loss > self.best_score - self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            # if the counter is greater than the patience, stop the training
            if self.counter >= self.patience:
                return True, self.model

        # if the score is better than the best score, reset the counter and save the model
        else:
            print(f"Validation loss decreased ({self.best_score:.6f} --> {val_loss:.6f}).  Saving model ..."
                  f"run since best: {self.counter}")
            self.best_score = val_loss
            self.model = deepcopy(model)
            self.counter = 0
            return False, self.model

        return False, self.model

# %%
# Neural Network class
class Net(nn.Module):
    """Neural Network class"""
    def __init__(self, input_size, h1, h2, h3):
        """
        Initialized the neural network with 3 hidden layers, with different sizes
        :param input_size: the size of the input layer
        :param h1: the size of the first hidden layer
        :param h2: size of the second hidden layer
        :param h3: size of the third hidden layer
        """
        super().__init__()
        self.fc1 = nn.Linear(input_size, h1)
        self.fc2 = nn.Linear(h1, h2)
        self.fc3 = nn.Linear(h2, h3)
        self.fc4 = nn.Linear(h3, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return torch.sigmoid(x)

# %%
def ham_accuracy(y_pred, y_true):
    """
    Calculate the accuracy of the ham
    :param y_pred: the prediction
    :param y_true: the true value
    :return: the accuracy of the ham
    """
    # round the prediction
    y_pred = torch.round(y_pred)
    # see if its a ham if it is check if pred is correct
    total = 0
    correct = 0
    for i in range(len(y_true)):
        if y_true[i] == 0: # its ham so check if pred is correct
            total += 1
            if y_pred[i] == 0:
                correct += 1

    return correct/total

# %%
# Data Config
EPOCH = 1000
CUTOFF = 0.01
# percent saved for validation
VAL = 0.2

# %%
list_of_file = ["balanced_trim_compiled_10.csv", "balanced_trim_compiled_20.csv", "balanced_trim_compiled_30.csv",
                "balanced_trim_compiled_40.csv", "balanced_trim_compiled_50.csv", "balanced_trim_compiled_60.csv",
                "balanced_trim_compiled_70.csv", "balanced_trim_compiled_80.csv", "balanced_trim_compiled_90.csv",
                "balanced_trim_compiled_100.csv", "balanced_trim_compiled_145.csv"]

h1_list = [64, 128]
h2_list = [64, 128, 256]
h3_list = [64, 128]
lr_list = [0.001, 0.01]
batch_size_list = [32, 64]

total_run = len(list_of_file) * len(h1_list) * len(h2_list) * len(h3_list) * len(lr_list) * len(batch_size_list)
run_count = 0

# Validation data
VAL = 0.2

# best Parameters
best_score = 0.0
best_params = {"h1": 0, "h2": 0, "h3": 0, "lr": 0, "batch_size": 0, "val_loss": 1000, "file": ""}
best_model = None

start_time = datetime.now()

# try different file sets
for file in list_of_file:
    # load and split data
    dataset = pd.read_csv(file)
    n_feature = pd.read_csv(file).shape[1] - 1

    # get equal number of spam and ham
    dataset = dataset.sample(frac=1)
    dataset = dataset.groupby("spam").head(min(dataset["spam"].value_counts()))

    train_data, val_data = train_test_split(dataset, test_size=VAL, random_state=42)

    train_y = train_data["spam"].values
    train_x = train_data.drop(["spam"], axis=1).values
    val_y = val_data["spam"].values
    val_x = val_data.drop(["spam"], axis=1).values

    # grid search part
    for batch_size in batch_size_list:
        # create the data loaders
        train_data = TensorDataset(torch.from_numpy(train_x).float(), torch.from_numpy(train_y).float())
        train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
        val_data = TensorDataset(torch.from_numpy(val_x).float(), torch.from_numpy(val_y).float())
        val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True)

        # try different hyper parameters
        for h1 in h1_list:
            for h2 in h2_list:
                for h3 in h3_list:
                    for lr in lr_list:
                        run_count += 1
                        # create the model
                        model = Net(n_feature, h1, h2, h3)
                        # create the optimizer
                        optimizer = optim.Adam(model.parameters(), lr=lr)
                        # create the loss function
                        loss_function = nn.BCELoss()

                        # Configure the early stopping
                        early_stopping = EarlyStopping(patience=10, delta=0.001)

                        # start training for EPOCH epochs
                        print(f"[{run_count} / {total_run}] starting a new model, feature = {n_feature}, h1 = {h1}, h2 = {h2}, h3 = {h3}, lr = {lr}, batch_size = {batch_size}")
                        for epoch in range(EPOCH):
                            print(f"   Epoch {epoch + 1} of {EPOCH} \n    ", end="")

                            # train the model
                            for data in train_loader:
                                X, y = data
                                model.zero_grad()
                                output = model(X)
                                loss = loss_function(output, y.view(-1, 1))
                                loss.backward()
                                optimizer.step()

                            # validate the model
                            val_loss = 0
                            y_pred = []
                            y_true = []
                            total_output = []
                            for data in val_loader:
                                X, y = data
                                output = model(X)
                                # save the output just in case its done
                                y_pred.append(output)
                                y_true.append(y)
                                # calculate the loss
                                loss = loss_function(output, y.view(-1, 1))
                                val_loss += loss.item()
                            val_loss /= len(val_loader)

                            # early stopping
                            early_stop, model = early_stopping(val_loss, model)
                            if early_stop:
                                print("   Early stopping")
                                # check if the model is better than the best model
                                ham_a = ham_accuracy(torch.cat(y_pred), torch.cat(y_true))
                                if ham_a > best_score:
                                    print(f"   SUCCESS: model is better than the best model {ham_a} > {best_score}")
                                    best_score = ham_a
                                    best_params["h1"] = h1
                                    best_params["h2"] = h2
                                    best_params["h3"] = h3
                                    best_params["lr"] = lr
                                    best_params["batch_size"] = batch_size
                                    best_params["val_loss"] = val_loss
                                    best_params["file"] = file
                                    best_model = model
                                else:
                                    print(f"   FAILURE: model is not better than the best model {ham_a} < {best_score}")

                                print("Been running for: ", datetime.now() - start_time)
                                print()
                                break # exit the loop

# print the best model
print()
print(f"BEEP BOOP COMPLETED THIS TOOK {datetime.now() - start_time}")
print(f"Best model score: {best_score}")
print(f"Best model: {best_params}")
# Out:
# [1 / 528] starting a new model, feature = 9, h1 = 64, h2 = 64, h3 = 64, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2394098496879451
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    SUCCESS: model is better than the best model 0.8666345690900337 > 0.0
# Been running for:  0:00:06.605230
#
# [2 / 528] starting a new model, feature = 9, h1 = 64, h2 = 64, h3 = 64, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.22126191190909594
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    SUCCESS: model is better than the best model 0.9532980259990371 > 0.8666345690900337
# Been running for:  0:00:13.291549
#
# [3 / 528] starting a new model, feature = 9, h1 = 64, h2 = 64, h3 = 128, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24309132824419066
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8656716417910447 < 0.9532980259990371
# Been running for:  0:00:21.501396
#
# [4 / 528] starting a new model, feature = 9, h1 = 64, h2 = 64, h3 = 128, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.21370886015938595
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8685604236880116 < 0.9532980259990371
# Been running for:  0:00:30.327333
#
# [5 / 528] starting a new model, feature = 9, h1 = 64, h2 = 128, h3 = 64, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2726927789626643
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.823302840635532 < 0.9532980259990371
# Been running for:  0:00:38.662514
#
# [6 / 528] starting a new model, feature = 9, h1 = 64, h2 = 128, h3 = 64, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.23397306952392682
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9171882522869523 < 0.9532980259990371
# Been running for:  0:00:48.511899
#
# [7 / 528] starting a new model, feature = 9, h1 = 64, h2 = 128, h3 = 128, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24565753183560446
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8584496870486278 < 0.9532980259990371
# Been running for:  0:00:58.521527
#
# [8 / 528] starting a new model, feature = 9, h1 = 64, h2 = 128, h3 = 128, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.22863044898258522
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8984111699566683 < 0.9532980259990371
# Been running for:  0:01:10.505307
#
# [9 / 528] starting a new model, feature = 9, h1 = 64, h2 = 256, h3 = 64, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.23997347615659237
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8753009147809341 < 0.9532980259990371
# Been running for:  0:01:21.655278
#
# [10 / 528] starting a new model, feature = 9, h1 = 64, h2 = 256, h3 = 64, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.20961919595720246
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9277804525758305 < 0.9532980259990371
# Been running for:  0:01:34.048084
#
# [11 / 528] starting a new model, feature = 9, h1 = 64, h2 = 256, h3 = 128, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24697039712918922
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8781896966779008 < 0.9532980259990371
# Been running for:  0:01:46.092255
#
# [12 / 528] starting a new model, feature = 9, h1 = 64, h2 = 256, h3 = 128, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.21429320727474988
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8988926336061628 < 0.9532980259990371
# Been running for:  0:02:01.225553
#
# [13 / 528] starting a new model, feature = 9, h1 = 128, h2 = 64, h3 = 64, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24961467215325683
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9022628791526239 < 0.9532980259990371
# Been running for:  0:02:09.767992
#
# [14 / 528] starting a new model, feature = 9, h1 = 128, h2 = 64, h3 = 64, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.23203384748194367
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8762638420799229 < 0.9532980259990371
# Been running for:  0:02:19.060652
#
# [15 / 528] starting a new model, feature = 9, h1 = 128, h2 = 64, h3 = 128, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24348373268730938
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8935965334617236 < 0.9532980259990371
# Been running for:  0:02:27.949227
#
# [16 / 528] starting a new model, feature = 9, h1 = 128, h2 = 64, h3 = 128, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.23807924950961024
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9402985074626866 < 0.9532980259990371
# Been running for:  0:02:37.990492
#
# [17 / 528] starting a new model, feature = 9, h1 = 128, h2 = 128, h3 = 64, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.23628687733435072
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.869041887337506 < 0.9532980259990371
# Been running for:  0:02:47.486775
#
# [18 / 528] starting a new model, feature = 9, h1 = 128, h2 = 128, h3 = 64, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2314023626386188
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8680789600385171 < 0.9532980259990371
# Been running for:  0:02:58.373660
#
# [19 / 528] starting a new model, feature = 9, h1 = 128, h2 = 128, h3 = 128, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24351385052432306
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8805970149253731 < 0.9532980259990371
# Been running for:  0:03:08.481824
#
# [20 / 528] starting a new model, feature = 9, h1 = 128, h2 = 128, h3 = 128, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.22896242039860226
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9528165623495426 < 0.9532980259990371
# Been running for:  0:03:20.917806
#
# [21 / 528] starting a new model, feature = 9, h1 = 128, h2 = 256, h3 = 64, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24160505272448063
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8839672604718344 < 0.9532980259990371
# Been running for:  0:03:32.822968
#
# [22 / 528] starting a new model, feature = 9, h1 = 128, h2 = 256, h3 = 64, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2400058571365662
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8791526239768898 < 0.9532980259990371
# Been running for:  0:03:47.896660
#
# [23 / 528] starting a new model, feature = 9, h1 = 128, h2 = 256, h3 = 128, lr = 0.001, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2370109244075138
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8584496870486278 < 0.9532980259990371
# Been running for:  0:04:02.236476
#
# [24 / 528] starting a new model, feature = 9, h1 = 128, h2 = 256, h3 = 128, lr = 0.01, batch_size = 32
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2551318416954018
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8907077515647569 < 0.9532980259990371
# Been running for:  0:04:20.954437
#
# [25 / 528] starting a new model, feature = 9, h1 = 64, h2 = 64, h3 = 64, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2541586437728256
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8810784785748677 < 0.9532980259990371
# Been running for:  0:04:25.644893
#
# [26 / 528] starting a new model, feature = 9, h1 = 64, h2 = 64, h3 = 64, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2658397061750293
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9316321617717862 < 0.9532980259990371
# Been running for:  0:04:30.423115
#
# [27 / 528] starting a new model, feature = 9, h1 = 64, h2 = 64, h3 = 128, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24911703635007143
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8704862782859895 < 0.9532980259990371
# Been running for:  0:04:35.489567
#
# [28 / 528] starting a new model, feature = 9, h1 = 64, h2 = 64, h3 = 128, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2270073250401765
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9297063071738084 < 0.9532980259990371
# Been running for:  0:04:40.907078
#
# [29 / 528] starting a new model, feature = 9, h1 = 64, h2 = 128, h3 = 64, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24901880603283644
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8709677419354839 < 0.9532980259990371
# Been running for:  0:04:46.141985
#
# [30 / 528] starting a new model, feature = 9, h1 = 64, h2 = 128, h3 = 64, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.22950626886449754
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9099662975445354 < 0.9532980259990371
# Been running for:  0:04:51.658233
#
# [31 / 528] starting a new model, feature = 9, h1 = 64, h2 = 128, h3 = 128, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.25801958120428026
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9037072701011074 < 0.9532980259990371
# Been running for:  0:04:57.153537
#
# [32 / 528] starting a new model, feature = 9, h1 = 64, h2 = 128, h3 = 128, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.21541830012574792
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8988926336061628 < 0.9532980259990371
# Been running for:  0:05:03.260089
#
# [33 / 528] starting a new model, feature = 9, h1 = 64, h2 = 256, h3 = 64, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2510871689300984
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8545979778526721 < 0.9532980259990371
# Been running for:  0:05:09.138368
#
# [34 / 528] starting a new model, feature = 9, h1 = 64, h2 = 256, h3 = 64, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.223662331700325
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8883004333172846 < 0.9532980259990371
# Been running for:  0:05:15.906269
#
# [35 / 528] starting a new model, feature = 9, h1 = 64, h2 = 256, h3 = 128, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24774690042249858
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8704862782859895 < 0.9532980259990371
# Been running for:  0:05:22.626297
#
# [36 / 528] starting a new model, feature = 9, h1 = 64, h2 = 256, h3 = 128, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.23500641249120235
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8849301877708233 < 0.9532980259990371
# Been running for:  0:05:30.779493
#
# [37 / 528] starting a new model, feature = 9, h1 = 128, h2 = 64, h3 = 64, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24822813039645553
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8685604236880116 < 0.9532980259990371
# Been running for:  0:05:35.759176
#
# [38 / 528] starting a new model, feature = 9, h1 = 128, h2 = 64, h3 = 64, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.22004470112733543
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8637457871930669 < 0.9532980259990371
# Been running for:  0:05:41.040054
#
# [39 / 528] starting a new model, feature = 9, h1 = 128, h2 = 64, h3 = 128, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.25316886871587485
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8579682233991334 < 0.9532980259990371
# Been running for:  0:05:46.355837
#
# [40 / 528] starting a new model, feature = 9, h1 = 128, h2 = 64, h3 = 128, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2374020772986114
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8709677419354839 < 0.9532980259990371
# Been running for:  0:05:52.135381
#
# [41 / 528] starting a new model, feature = 9, h1 = 128, h2 = 128, h3 = 64, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24510069889947772
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8724121328839672 < 0.9532980259990371
# Been running for:  0:05:57.500551
#
# [42 / 528] starting a new model, feature = 9, h1 = 128, h2 = 128, h3 = 64, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.21245436230674386
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9041887337506018 < 0.9532980259990371
# Been running for:  0:06:03.728276
#
# [43 / 528] starting a new model, feature = 9, h1 = 128, h2 = 128, h3 = 128, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.23710745910648257
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8700048146364949 < 0.9532980259990371
# Been running for:  0:06:09.708284
#
# [44 / 528] starting a new model, feature = 9, h1 = 128, h2 = 128, h3 = 128, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.2402111147530377
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8772267693789119 < 0.9532980259990371
# Been running for:  0:06:16.494136
#
# [45 / 528] starting a new model, feature = 9, h1 = 128, h2 = 256, h3 = 64, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.24327518814243376
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.8757823784304285 < 0.9532980259990371
# Been running for:  0:06:23.250069
#
# [46 / 528] starting a new model, feature = 9, h1 = 128, h2 = 256, h3 = 64, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.23441352625377476
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
# ...
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.10587739611219149
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9546127281697089 < 0.9877750611246944
# Been running for:  1:16:39.315195
#
# [515 / 528] starting a new model, feature = 135, h1 = 64, h2 = 256, h3 = 128, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.11984504462452605
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9299457326097681 < 0.9877750611246944
# Been running for:  1:16:47.891708
#
# [516 / 528] starting a new model, feature = 135, h1 = 64, h2 = 256, h3 = 128, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.10291732937912457
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9871731623088308 < 0.9877750611246944
# Been running for:  1:16:58.338778
#
# [517 / 528] starting a new model, feature = 135, h1 = 128, h2 = 64, h3 = 64, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.10454336772090755
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9580661075481006 < 0.9877750611246944
# Been running for:  1:17:04.771511
#
# [518 / 528] starting a new model, feature = 135, h1 = 128, h2 = 64, h3 = 64, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.07734696441912092
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9723729649728663 < 0.9877750611246944
# Been running for:  1:17:11.315747
#
# [519 / 528] starting a new model, feature = 135, h1 = 128, h2 = 64, h3 = 128, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.10435683574178256
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9694129255056734 < 0.9877750611246944
# Been running for:  1:17:17.976591
#
# [520 / 528] starting a new model, feature = 135, h1 = 128, h2 = 64, h3 = 128, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.10051010618917644
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9481993093241243 < 0.9877750611246944
# Been running for:  1:17:25.745765
#
# [521 / 528] starting a new model, feature = 135, h1 = 128, h2 = 128, h3 = 64, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.125516886706464
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9768130241736557 < 0.9877750611246944
# Been running for:  1:17:32.533398
#
# [522 / 528] starting a new model, feature = 135, h1 = 128, h2 = 128, h3 = 64, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.07867572209215723
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9748396645288604 < 0.9877750611246944
# Been running for:  1:17:40.509972
#
# [523 / 528] starting a new model, feature = 135, h1 = 128, h2 = 128, h3 = 128, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.10183117841370404
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9521460286137149 < 0.9877750611246944
# Been running for:  1:17:47.455631
#
# [524 / 528] starting a new model, feature = 135, h1 = 128, h2 = 128, h3 = 128, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.08167747844709083
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9723729649728663 < 0.9877750611246944
# Been running for:  1:17:55.642686
#
# [525 / 528] starting a new model, feature = 135, h1 = 128, h2 = 256, h3 = 64, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.10962539436877705
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9699062654168722 < 0.9877750611246944
# Been running for:  1:18:03.959825
#
# [526 / 528] starting a new model, feature = 135, h1 = 128, h2 = 256, h3 = 64, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.08709720773913432
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9733596447952639 < 0.9877750611246944
# Been running for:  1:18:13.704415
#
# [527 / 528] starting a new model, feature = 135, h1 = 128, h2 = 256, h3 = 128, lr = 0.001, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.11222709971480072
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.978786383818451 < 0.9877750611246944
# Been running for:  1:18:21.753911
#
# [528 / 528] starting a new model, feature = 135, h1 = 128, h2 = 256, h3 = 128, lr = 0.01, batch_size = 64
#    Epoch 1 of 1000
#     Run number 1 Initial validation loss: 0.1272307827603072
#    Epoch 2 of 1000
#     Run number 2 EarlyStopping counter: 1 out of 10
#    Epoch 3 of 1000
#     Run number 3 EarlyStopping counter: 2 out of 10
#    Epoch 4 of 1000
#     Run number 4 EarlyStopping counter: 3 out of 10
#    Epoch 5 of 1000
#     Run number 5 EarlyStopping counter: 4 out of 10
#    Epoch 6 of 1000
#     Run number 6 EarlyStopping counter: 5 out of 10
#    Epoch 7 of 1000
#     Run number 7 EarlyStopping counter: 6 out of 10
#    Epoch 8 of 1000
#     Run number 8 EarlyStopping counter: 7 out of 10
#    Epoch 9 of 1000
#     Run number 9 EarlyStopping counter: 8 out of 10
#    Epoch 10 of 1000
#     Run number 10 EarlyStopping counter: 9 out of 10
#    Epoch 11 of 1000
#     Run number 11 EarlyStopping counter: 10 out of 10
#    Early stopping
#    FAILURE: model is not better than the best model 0.9551060680809077 < 0.9877750611246944
# Been running for:  1:18:32.872342
#
#
# BEEP BOOP COMPLETED THIS TOOK 1:18:32.872342
# Best model: {'h1': 64, 'h2': 64, 'h3': 128, 'lr': 0.01, 'batch_size': 32, 'val_loss': 0.1471236188081093, 'file': 'balanced_trim_compiled_70.csv'}

# %%
# save the best model
torch.save(best_model.state_dict(), "best_model.pt")
